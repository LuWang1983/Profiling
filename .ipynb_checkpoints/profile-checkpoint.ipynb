# %%
# Development
# Import algorithms, methods and dataset from libraries

from pandas import read_csv
import numpy as np
from pandas.plotting import scatter_matrix

# visualize your data
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)
# %matplotlib inline

# data split and cross validation
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

#algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Load dataset and define features
url = "PIRUS_May2020/PIRUS_Public_May2020.csv"
dataset = read_csv(url)
print(dataset.head(10))
print(dataset.describe())
# 
scatter_matrix(dataset)
plt.show()
# Out:
#    Subject_ID Loc_Plot_State1 Loc_Plot_City1 Loc_Plot_State2 Loc_Plot_City2  \
# 0        1178        Virginia       Quantico  North Carolina        Raleigh
# 1        2010        Delaware         Newark           Yemen         Sana'a
# 2        2011   Massachusetts         Malden     Afghanistan            -99
# 3        2051           Texas        Houston             NaN            NaN
# 4        2063      Washington            -99     Afghanistan            NaN
# 5        2204        Michigan        Detroit             NaN            NaN
# 6        2233       Minnesota    Minneapolis             NaN            NaN
# 7        3207        Illinois       Westmont             NaN            NaN
# 8        3275        New York            -99             NaN            NaN
# 9        3289        New York       New York             NaN            NaN
#
#   Date_Exposure  Plot_Target1  Plot_Target2  Plot_Target3  Attack_Preparation  \
# 0       7/27/09           -88           NaN           NaN                 -88
# 1       3/12/10           -88           NaN           NaN                 -88
# 2        7/1/08             4           NaN           NaN                   0
# 3       11/1/06           -88           NaN           NaN                 -88
# 4       8/30/02           -88           NaN           NaN                 -88
# 5       5/16/08           -88           NaN           NaN                 -88
# 6      10/27/09           -88           NaN           NaN                 -88
# 7       3/29/91           -88           NaN           NaN                 -88
# 8       10/1/90           -88           NaN           NaN                 -88
# 9        7/3/92           -88           NaN           NaN                 -88
#
#    ...  Previous_Criminal_Activity_Type2  Previous_Criminal_Activity_Type3  \
# 0  ...                              19.0                              20.0
# 1  ...                               NaN                               NaN
# 2  ...                               NaN                               NaN
# 3  ...                               NaN                               NaN
# 4  ...                              10.0                               NaN
# 5  ...                               NaN                               NaN
# 6  ...                               NaN                               NaN
# 7  ...                               NaN                               NaN
# 8  ...                               NaN                               NaN
# 9  ...                               NaN                               NaN
#
#    Previous_Criminal_Activity_Age  Gang  Gang_Age_Joined  Trauma  \
# 0                               1     0              -88       0
# 1                             -88     0              -88       0
# 2                             -88     0              -88     -99
# 3                             -99     0              -88     -99
# 4                               3     0              -88     -99
# 5                             -99     0              -88     -99
# 6                             -99     0              -88     -99
# 7                             -99     0              -88     -99
# 8                             -99     0              -88     -99
# 9                             -99     0              -88     -99
#
#    Other_Ideologies  Angry_US  Group_Grievance  Standing
# 0                 0       -99              -99       -99
# 1                 0         0                0         0
# 2                 0       -99              -99         0
# 3                 0       -99              -99       -99
# 4                 1         1                1       -99
# 5                 0       -99              -99       -99
# 6                 0       -99              -99       -99
# 7                 0         1                1       -99
# 8                 0       -99                1       -99
# 9                 0       -99                1       -99
#
# [10 rows x 145 columns]
#         Subject_ID  Plot_Target1  Plot_Target2  Plot_Target3  \
# count  2226.000000   2226.000000    259.000000     95.000000
# mean   4901.200359    -39.863432      8.324324     10.084211
# std    1744.632869     48.461928      5.947039      5.791893
# min    1000.000000    -99.000000      1.000000      1.000000
# 25%    3760.500000    -88.000000      3.000000      6.000000
# 50%    5000.500000      1.000000      6.000000     14.000000
# 75%    6295.000000      7.000000     14.000000     14.000000
# max    9550.000000     20.000000     20.000000     20.000000
#
#        Attack_Preparation  Op_Security  Changing_Target  Anticp_Fatals_Targ  \
# count         2226.000000  2226.000000      2226.000000         2226.000000
# mean           -51.411051   -61.352650       -58.791554          -54.078616
# std             45.035192    43.357869        43.609479           44.794348
# min            -99.000000   -99.000000       -99.000000          -99.000000
# 25%            -88.000000   -88.000000       -88.000000          -88.000000
# 50%            -88.000000   -88.000000       -88.000000          -88.000000
# 75%              1.000000     1.000000         0.000000            1.000000
# max              3.000000     2.000000         1.000000            3.000000
#
#        Internet_Use_Plot  Extent_Plot  ...  Previous_Criminal_Activity_Type1  \
# count        2226.000000  2226.000000  ...                       2226.000000
# mean          -73.419137     0.969901  ...                        -70.472597
# std            35.377629    10.669140  ...                         43.595025
# min           -99.000000   -99.000000  ...                        -99.000000
# 25%           -88.000000     0.000000  ...                        -99.000000
# 50%           -88.000000     1.000000  ...                        -88.000000
# 75%           -88.000000     5.000000  ...                        -88.000000
# max             1.000000     5.000000  ...                         20.000000
#
#        Previous_Criminal_Activity_Type2  Previous_Criminal_Activity_Type3  \
# count                        267.000000                        122.000000
# mean                          12.191011                         14.803279
# std                            6.144641                          5.349966
# min                            3.000000                          1.000000
# 25%                            6.000000                          9.000000
# 50%                           13.000000                         17.500000
# 75%                           18.000000                         19.000000
# max                           20.000000                         20.000000
#
#        Previous_Criminal_Activity_Age         Gang       Trauma  \
# count                     2226.000000  2226.000000  2226.000000
# mean                       -73.305031    -0.387242   -74.955526
# std                         39.962971     6.285929    42.654971
# min                        -99.000000   -99.000000   -99.000000
# 25%                        -99.000000     0.000000   -99.000000
# 50%                        -88.000000     0.000000   -99.000000
# 75%                        -88.000000     0.000000   -99.000000
# max                          5.000000     3.000000     3.000000
#
#        Other_Ideologies     Angry_US  Group_Grievance     Standing
# count       2226.000000  2226.000000      2226.000000  2226.000000
# mean          -0.326595   -38.000898       -40.345013   -76.457772
# std            5.929760    48.596083        49.522815    41.625492
# min          -99.000000   -99.000000       -99.000000   -99.000000
# 25%            0.000000   -99.000000       -99.000000   -99.000000
# 50%            0.000000     0.000000         0.000000   -99.000000
# 75%            0.000000     1.000000         2.000000   -99.000000
# max            1.000000     1.000000         3.000000     3.000000
#
# [8 rows x 124 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c0fc5f097f0a> in <module>
#       1 # histograms
# ----> 2 scatter_matrix(dataset)
#       3 plt.show()
#
# NameError: name 'scatter_matrix' is not defined

# %%
# Split-out validation dataset to a 8:2 ratio. 80% for training, 20% for testing
array = dataset.values
print(array)
X = array[:,0:4]
y = array[:,4]
# print(X)
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1, shuffle=True)

# Spot Check Algorithms - compare different models to pick the best model
# does not need to be included in the final model
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# Out:
# [[1178 'Virginia' 'Quantico' ... -99 -99 -99]
#  [2010 'Delaware' 'Newark' ... 0 0 0]
#  [2011 'Massachusetts' 'Malden' ... -99 -99 0]
#  ...
#  [7476 'Pennsylvania' 'Avalon' ... 0 0 -99]
#  [7161 'South Carolina' 'Anderson' ... 1 0 0]
#  [8341 'Utah' 'St. George' ... 1 0 0]]
